# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300

# %%
women_degrees = pd.read_csv("percent-bachelors-degrees-women-usa.csv")

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']
fig = plt.figure(figsize=(12, 12))

for sp in range(0, 4):
    ax = fig.add_subplot(2, 2, sp + 1)
    ax.plot(women_degrees['Year'], women_degrees[major_cats[sp]], c = 'blue', label = 'Women')
    ax.plot(women_degrees['Year'], 100 - women_degrees[major_cats[sp]], c = 'green', label = 'Men')
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False)
    ax.set_title(major_cats[sp])
# Calling pyplot.legend() here will add the legend to the last subplot that was created.
plt.legend(loc = 'upper right')
plt.show()

# %%
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)
fig = plt.figure(figsize = (18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1, 6, sp + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[sp]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False)
    if sp == 0:
        ax.text(2005, 87, "Men")
        ax.text(2002, 8, "Women")
    elif sp == 5:
        ax.text(2005, 62, "Men")
        ax.text(2001, 35, "Women")
    else:
        pass

plt.show()

# %%
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)
cb_light_gray = (171/255, 171/255, 171/255)
fig = plt.figure(figsize = (18, 30))

for sp in range(0, 18, 3):
    index = int(sp / 3)
    ax = fig.add_subplot(6, 3, sp + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[index]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[index])
    ax.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False)
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    if index == 0:
        ax.text(2005, 87, "Men")
        ax.text(2002, 8, "Women")
    elif index == 5:
        ax.text(2005, 62, "Men")
        ax.text(2001, 35, "Women")
    else:
        pass

for sq in range(1, 16, 3):
    index = int((sq - 1) / 3)
    ax2 = fig.add_subplot(6, 3, sq + 1)
    ax2.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax2.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[index]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax2.spines.items():
        spine.set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0, 100)
    ax2.set_title(lib_arts_cats[index])
    ax2.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False)
    ax2.axhline(50, c = cb_light_gray, alpha = 0.3)
    if index == 0:
        ax2.text(2005, 80, "Women")
        ax2.text(2002, 20, "Men")
    else:
        pass

for sr in range(2, 20, 3):
    index = int((sr - 2) / 3)
    ax3 = fig.add_subplot(6, 3, sr + 1)
    ax3.plot(women_degrees['Year'], women_degrees[other_cats[index]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax3.plot(women_degrees['Year'], 100 - women_degrees[other_cats[index]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax3.spines.items():
        spine.set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0, 100)
    ax3.set_title(other_cats[index])
    ax3.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False)
    ax3.axhline(50, c = cb_light_gray, alpha = 0.3)
    if index == 0:
        ax3.text(2007, 90, "Women")
        ax3.text(2006, 7, "Men")    
    elif index == 5:
        ax3.text(2005, 62, "Men")
        ax3.text(2002, 35, "Women")
    else:
        pass
    
plt.show()

# %%
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)
fig = plt.figure(figsize = (18, 30))

for sp in range(0, 18, 3):
    index = int(sp / 3)
    ax = fig.add_subplot(6, 3, sp + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[index]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[index])
    ax.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    if index == 0:
        ax.text(2005, 87, "Men")
        ax.text(2002, 8, "Women")
        ax.tick_params(axis = 'x', labelbottom = True)
    elif index == 5:
        ax.text(2005, 62, "Men")
        ax.text(2001, 35, "Women")
        ax.tick_params(axis = 'x', labelbottom = True)
    else:
        pass

for sq in range(1, 16, 3):
    index = int((sq - 1) / 3)
    ax2 = fig.add_subplot(6, 3, sq + 1)
    ax2.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax2.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[index]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax2.spines.items():
        spine.set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0, 100)
    ax2.set_title(lib_arts_cats[index])
    ax2.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False, labelbottom = False)
    ax2.set_yticks([0,100])
    ax2.axhline(50, c = cb_light_gray, alpha = 0.3)
    if index == 0:
        ax2.text(2005, 80, "Women")
        ax2.text(2002, 20, "Men")
        ax2.tick_params(axis = 'x', labelbottom = True)
    elif index == 4:
        ax2.tick_params(axis = 'x', labelbottom = True)
    else:
        pass

for sr in range(2, 20, 3):
    index = int((sr - 2) / 3)
    ax3 = fig.add_subplot(6, 3, sr + 1)
    ax3.plot(women_degrees['Year'], women_degrees[other_cats[index]], c = cb_dark_blue, label = 'Women', linewidth = 3)
    ax3.plot(women_degrees['Year'], 100 - women_degrees[other_cats[index]], c = cb_orange, label = 'Men', linewidth = 3)
    for key,spine in ax3.spines.items():
        spine.set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0, 100)
    ax3.set_title(other_cats[index])
    ax3.tick_params(axis = 'both', which = 'both', bottom = False, top = False, left = False, right = False, labelbottom = False)
    ax3.set_yticks([0,100])
    ax3.axhline(50, c = cb_light_gray, alpha = 0.3)
    if index == 0:
        ax3.text(2007, 90, "Women")
        ax3.text(2006, 7, "Men")
        ax3.tick_params(axis = 'x', labelbottom = True)
    elif index == 5:
        ax3.text(2005, 62, "Men")
        ax3.text(2002, 35, "Women")
        ax3.tick_params(axis = 'x', labelbottom = True)
    else:
        pass
    
plt.savefig("gender_degrees.png")
plt.show()
